# %%
###
### SORT ACCORDING TO COLUMN
###

import sys, csv ,operator
data = csv.reader(open('import_data/publishers.csv'))
sortedlist = sorted(data, key=operator.itemgetter(1))    # 1 specifies according to first column we want to sort
#now write the sorte result into new CSV file
with open("import_data/publishers_sorted.csv", "w") as f:
  fileWriter = csv.writer(f, delimiter=',')
  for row in sortedlist:
      fileWriter.writerow(row)

# %%
###
### DEDUPLICATE DATA (check manually at the end)
###

reader=csv.reader(open('import_data/publishers_sorted.csv', 'r'), delimiter=',')
writer=csv.writer(open('import_data/publishers_sorted_distinct.csv', 'w'), delimiter=',')

entries = set()

for row in reader:
   key = (row[0], row[1]) # instead of just the last name

   if key not in entries:
      writer.writerow(row)
      entries.add(key)

# %%
###
### READ THE CSV
###

f = open('import_data/publishers_sorted_distinct.csv')
csv_f = csv.reader(f)   
data = []

for row in csv_f: 
   data.append(row)
f.close()

## TEST COSA C'È NELLE LINEE SPECIFICATE
print(data[1:3])
# Out:
# [['Lausanne', 'Amis de C. F. Landry'], ['Lausanne et Carrouge', 'Association des Amis de Gustave Roud']]

# %%
###
### TRANSFORM INTO XML FOR BULK IMPORT INTO KNORA
###


def convert_row(row):
    return """
    <p0112-roud-oeuvres:Publisher id="edi_%s">
        <knoraXmlImport:label>edi_%s</knoraXmlImport:label>
        <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">%s</p0112-roud-oeuvres:publisherHasLocation>
        <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">%s</p0112-roud-oeuvres:publisherHasName>
    </p0112-roud-oeuvres:Publisher>
    """ % (row[1], row[1], row[0], row[1])

print('\n'.join([convert_row(row) for row in data[1:]]))
# Out:
#     <p0112-roud-oeuvres:Publisher id="edi_Amis de C. F. Landry">
#         <knoraXmlImport:label>edi_Amis de C. F. Landry</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Amis de C. F. Landry</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Association des Amis de Gustave Roud">
#         <knoraXmlImport:label>edi_Association des Amis de Gustave Roud</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne et Carrouge</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Association des Amis de Gustave Roud</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Atelier Saint-Prex et Jean Genoud">
#         <knoraXmlImport:label>edi_Atelier Saint-Prex et Jean Genoud</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Atelier Saint-Prex et Jean Genoud</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Au Verseau">
#         <knoraXmlImport:label>edi_Au Verseau</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Au Verseau</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Bertil Galland">
#         <knoraXmlImport:label>edi_Bertil Galland</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Vevey</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Bertil Galland</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Bibliothèque des Arts">
#         <knoraXmlImport:label>edi_Bibliothèque des Arts</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Bibliothèque des Arts</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Chambre économique du Jura">
#         <knoraXmlImport:label>edi_Chambre économique du Jura</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value"></p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Chambre économique du Jura</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Clairefontaine">
#         <knoraXmlImport:label>edi_Clairefontaine</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Clairefontaine</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Corti">
#         <knoraXmlImport:label>edi_Corti</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Corti</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Cyclades">
#         <knoraXmlImport:label>edi_Cyclades</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Nyon</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Cyclades</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Delpire">
#         <knoraXmlImport:label>edi_Delpire</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Delpire</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Edition du Lien">
#         <knoraXmlImport:label>edi_Edition du Lien</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Leysin</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Edition du Lien</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Editions Vie">
#         <knoraXmlImport:label>edi_Editions Vie</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Editions Vie</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Editions du Comte-Vert">
#         <knoraXmlImport:label>edi_Editions du Comte-Vert</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value"></p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Editions du Comte-Vert</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_FIPF">
#         <knoraXmlImport:label>edi_FIPF</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Sèvres</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">FIPF</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Fario">
#         <knoraXmlImport:label>edi_Fario</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Fario</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Fata Morgana">
#         <knoraXmlImport:label>edi_Fata Morgana</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Montpellier</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Fata Morgana</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Fondation Jan Michalski pour l'écriture et la littérature">
#         <knoraXmlImport:label>edi_Fondation Jan Michalski pour l'écriture et la littérature</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Montricher</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Fondation Jan Michalski pour l'écriture et la littérature</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Gallimard">
#         <knoraXmlImport:label>edi_Gallimard</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Gallimard</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Gallimard ("Les Cahiers de la NRF")">
#         <knoraXmlImport:label>edi_Gallimard ("Les Cahiers de la NRF")</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Gallimard ("Les Cahiers de la NRF")</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Guilde du livre">
#         <knoraXmlImport:label>edi_Guilde du livre</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Guilde du livre</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Horizons de France, “Champs”">
#         <knoraXmlImport:label>edi_Horizons de France, “Champs”</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Horizons de France, “Champs”</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Imprimerie Held">
#         <knoraXmlImport:label>edi_Imprimerie Held</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Imprimerie Held</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Infolio">
#         <knoraXmlImport:label>edi_Infolio</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Gollion</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Infolio</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_J. R. Geigy">
#         <knoraXmlImport:label>edi_J. R. Geigy</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Bâle</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">J. R. Geigy</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_J.-M. Place">
#         <knoraXmlImport:label>edi_J.-M. Place</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">J.-M. Place</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_J.R. Geigy">
#         <knoraXmlImport:label>edi_J.R. Geigy</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Bâle</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">J.R. Geigy</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Jean Guérin est un pseudonyme derrière lequel se cachent tous les membres du comité du prériodique, mais surtout Paulhan, comme c'est le cas ici.">
#         <knoraXmlImport:label>edi_Jean Guérin est un pseudonyme derrière lequel se cachent tous les membres du comité du prériodique, mais surtout Paulhan, comme c'est le cas ici.</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Jean Guérin est un pseudonyme derrière lequel se cachent tous les membres du comité du prériodique, mais surtout Paulhan, comme c'est le cas ici.</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_José Corti">
#         <knoraXmlImport:label>edi_José Corti</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">José Corti</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Kandelaber Verlag">
#         <knoraXmlImport:label>edi_Kandelaber Verlag</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Berne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Kandelaber Verlag</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_L'Aire">
#         <knoraXmlImport:label>edi_L'Aire</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Vevey</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">L'Aire</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_L'Aire">
#         <knoraXmlImport:label>edi_L'Aire</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">L'Aire</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_L'Aire ("Coopérative Rencontre")">
#         <knoraXmlImport:label>edi_L'Aire ("Coopérative Rencontre")</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">L'Aire ("Coopérative Rencontre")</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_L'Âge d'Homme">
#         <knoraXmlImport:label>edi_L'Âge d'Homme</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">L'Âge d'Homme</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_L'Âge d'homme">
#         <knoraXmlImport:label>edi_L'Âge d'homme</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">L'Âge d'homme</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Baconnière">
#         <knoraXmlImport:label>edi_La Baconnière</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Neuchâtel</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Baconnière</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Bibliothèque des Arts">
#         <knoraXmlImport:label>edi_La Bibliothèque des Arts</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Bibliothèque des Arts</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Dogana">
#         <knoraXmlImport:label>edi_La Dogana</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Genève</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Dogana</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Délirante">
#         <knoraXmlImport:label>edi_La Délirante</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Délirante</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Guilde du Livre">
#         <knoraXmlImport:label>edi_La Guilde du Livre</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Guilde du Livre</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Guilde du livre">
#         <knoraXmlImport:label>edi_La Guilde du livre</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Guilde du livre</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Guilde du livre">
#         <knoraXmlImport:label>edi_La Guilde du livre</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne et Carrouge</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Guilde du livre</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Guilde du livre">
#         <knoraXmlImport:label>edi_La Guilde du livre</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value"></p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Guilde du livre</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Manufacture">
#         <knoraXmlImport:label>edi_La Manufacture</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lyon</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Manufacture</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_La Suisse, Société d'assurances">
#         <knoraXmlImport:label>edi_La Suisse, Société d'assurances</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">La Suisse, Société d'assurances</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Le Verseau">
#         <knoraXmlImport:label>edi_Le Verseau</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Le Verseau</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Les Cahiers du Sud">
#         <knoraXmlImport:label>edi_Les Cahiers du Sud</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Marseille</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Les Cahiers du Sud</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Les Chantres">
#         <knoraXmlImport:label>edi_Les Chantres</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Etoy</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Les Chantres</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Max Roth">
#         <knoraXmlImport:label>edi_Max Roth</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Max Roth</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Mermod">
#         <knoraXmlImport:label>edi_Mermod</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Mermod</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Mermod ("Aujourd'hui")">
#         <knoraXmlImport:label>edi_Mermod ("Aujourd'hui")</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Mermod ("Aujourd'hui")</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Musée cantonal des Beaux-Arts">
#         <knoraXmlImport:label>edi_Musée cantonal des Beaux-Arts</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Musée cantonal des Beaux-Arts</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Musée des Beaux-Arts">
#         <knoraXmlImport:label>edi_Musée des Beaux-Arts</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Vevey</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Musée des Beaux-Arts</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_NRF, Bibliothèque de la Pléiade">
#         <knoraXmlImport:label>edi_NRF, Bibliothèque de la Pléiade</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">NRF, Bibliothèque de la Pléiade</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_PUBLISHER">
#         <knoraXmlImport:label>edi_PUBLISHER</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">PLACE</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">PUBLISHER</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Paul Castella">
#         <knoraXmlImport:label>edi_Paul Castella</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Albeuve</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Paul Castella</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Payot">
#         <knoraXmlImport:label>edi_Payot</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Payot</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Payot, Centre de recherches sur les lettres romandes">
#         <knoraXmlImport:label>edi_Payot, Centre de recherches sur les lettres romandes</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Dorigny</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Payot, Centre de recherches sur les lettres romandes</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Peter Lang">
#         <knoraXmlImport:label>edi_Peter Lang</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">New York et alii</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Peter Lang</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Pierre Cailler">
#         <knoraXmlImport:label>edi_Pierre Cailler</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Genève</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Pierre Cailler</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Pierre Seghers, coll. Poètes d'aujourd'hui, no 173">
#         <knoraXmlImport:label>edi_Pierre Seghers, coll. Poètes d'aujourd'hui, no 173</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Paris</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Pierre Seghers, coll. Poètes d'aujourd'hui, no 173</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Pour l'Art">
#         <knoraXmlImport:label>edi_Pour l'Art</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Pour l'Art</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Presse universitaire de Strasbourg">
#         <knoraXmlImport:label>edi_Presse universitaire de Strasbourg</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Strasbourg</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Presse universitaire de Strasbourg</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Raynald Métraux">
#         <knoraXmlImport:label>edi_Raynald Métraux</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Raynald Métraux</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Rencontre">
#         <knoraXmlImport:label>edi_Rencontre</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Rencontre</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Schweizer Bücherfreunde">
#         <knoraXmlImport:label>edi_Schweizer Bücherfreunde</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">[Zurich]</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Schweizer Bücherfreunde</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Slatkine">
#         <knoraXmlImport:label>edi_Slatkine</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Genève</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Slatkine</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Société de la feuille d'avis de Lausanne, coll. Le Livre du Mois">
#         <knoraXmlImport:label>edi_Société de la feuille d'avis de Lausanne, coll. Le Livre du Mois</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Société de la feuille d'avis de Lausanne, coll. Le Livre du Mois</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Sources - Revue de la Maison de la Poésie">
#         <knoraXmlImport:label>edi_Sources - Revue de la Maison de la Poésie</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Namur</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Sources - Revue de la Maison de la Poésie</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Union suisse des paysans">
#         <knoraXmlImport:label>edi_Union suisse des paysans</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Brougg</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Union suisse des paysans</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_V. Porchet">
#         <knoraXmlImport:label>edi_V. Porchet</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">V. Porchet</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Zofingue">
#         <knoraXmlImport:label>edi_Zofingue</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value"></p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Zofingue</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Zollikofer">
#         <knoraXmlImport:label>edi_Zollikofer</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Saint-Gall</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Zollikofer</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Zoé">
#         <knoraXmlImport:label>edi_Zoé</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Genève-Carrouge</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Zoé</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Zoé">
#         <knoraXmlImport:label>edi_Zoé</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Carouge-Genève</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Zoé</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Zoé">
#         <knoraXmlImport:label>edi_Zoé</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Genève</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Zoé</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_s.n.é.">
#         <knoraXmlImport:label>edi_s.n.é.</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value"></p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">s.n.é.</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Éditions Clairefontaine Lausanne ">
#         <knoraXmlImport:label>edi_Éditions Clairefontaine Lausanne </knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Éditions Clairefontaine Lausanne </p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Éditions Empreintes">
#         <knoraXmlImport:label>edi_Éditions Empreintes</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Moudon</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Éditions Empreintes</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Éditions Paroles Lausanne">
#         <knoraXmlImport:label>edi_Éditions Paroles Lausanne</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Éditions Paroles Lausanne</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Éditions Rencontre">
#         <knoraXmlImport:label>edi_Éditions Rencontre</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Éditions Rencontre</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Éditions de Mon Repos">
#         <knoraXmlImport:label>edi_Éditions de Mon Repos</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Éditions de Mon Repos</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Éditions des Portes de France">
#         <knoraXmlImport:label>edi_Éditions des Portes de France</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Porrentruy</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Éditions des Portes de France</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Éditions des Terreaux">
#         <knoraXmlImport:label>edi_Éditions des Terreaux</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Éditions des Terreaux</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
#
#
#     <p0112-roud-oeuvres:Publisher id="edi_Études de lettres">
#         <knoraXmlImport:label>edi_Études de lettres</knoraXmlImport:label>
#         <p0112-roud-oeuvres:publisherHasLocation knoraType="richtext_value">Lausanne</p0112-roud-oeuvres:publisherHasLocation>
#         <p0112-roud-oeuvres:publisherHasName knoraType="richtext_value">Études de lettres</p0112-roud-oeuvres:publisherHasName>
#     </p0112-roud-oeuvres:Publisher>
